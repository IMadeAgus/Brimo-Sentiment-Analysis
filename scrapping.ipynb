# %%
from google_play_scraper import reviews
import pandas as pd
import os

# %%
# Mengambil ulasan
scrapreview, _ = reviews(
    'id.co.bri.brimo',
    lang='id',
    country='id',
    count=50000
)

# %%
app_reviews_df = pd.DataFrame(scrapreview)
app_reviews_df.head()
# Out:
#                                reviewId         userName  \
# 0  8b8b79fc-58d7-40d4-bde8-397010fbfa5d  Pengguna Google
# 1  ebe3c116-749f-44fa-9354-f56d86f6e556  Pengguna Google
# 2  a534f6d5-bc7b-447f-bcc6-dda7f03f2a4a  Pengguna Google
# 3  6fd32a26-25f1-4b5b-a1d8-04fa32f6f90a  Pengguna Google
# 4  0bd6f0c1-0fe6-4818-894c-068d07ef58c6  Pengguna Google
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0  sudah mantap... tetapi kok susah dilanjutkan j...      5              0
# 1                                 sangat puas sekali      5              0
# ...

# %%
# os.mkdir('dataset')
app_reviews_df.to_csv("dataset/review_app_brimo2.csv", index=False)
